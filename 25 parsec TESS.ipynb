# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %matplotlib inline

# %%
tess = pd.read_csv("/Users/student/Desktop/SRMPBrownDwarf/database/TESS_crossmatch.csv",comment="#")

# %%
kepler = pd.read_csv("/Users/student/Desktop/SRMPBrownDwarf/database/Kepler_crossmatch.csv")

# %%
K2 = pd.read_csv("/Users/student/Desktop/SRMPBrownDwarf/database/K2_crossmatch.csv")
sample = pd.read_csv("/Users/student/Desktop/SRMPBrownDwarf/database/finalsample_bf1sig_468_recovered_2019feb23 - finalsample_bf1sig_468_recovered_2019feb23.csv")

# %%
tess.shape
# Out:
# (442, 127)

# %%
tess
# Out:
#        RA (deg)  Dec (deg)     MatchID     MatchRa   MatchDEC  dstArcSec  \
# 0     38.956600  -7.189300     4715901   38.956600  -7.189300   0.000000
# 1    162.052400 -11.335600   471015913  162.052400 -11.335600   0.000000
# 2    343.827583 -57.218239   220487652  343.827582 -57.218239   0.002565
# 3    153.358208 -78.715317   394394502  153.358216 -78.715316   0.006037
# 4     12.361542  -6.596308     3958591   12.361544  -6.596309   0.008672
# 5    243.926900   5.777800   315553194  243.926901   5.777796   0.014845
# 6    173.728900   0.381700   380544811  173.728895   0.381701   0.018301
# 7     70.906708   0.034750   299007548   70.906703   0.034753   0.019402
# 8    181.126500  32.216530   359030011  181.126494  32.216533   0.019868
# 9    219.868200  19.487500   349289826  219.868204  19.487495   0.022545
# 10   269.234200 -48.086000   390136783  269.234200 -48.086008   0.029200
# 11    67.326800 -31.399100   170675902   67.326796 -31.399092   0.031313
# ...

# %%
kepler.shape
# Out:
# (2, 22)

# %%
K2.shape
# Out:
# (62, 39)

# %%
sample.shape
# Out:
# (468, 275)

# %%
tess.columns[0:100],tess.columns[100:],
# Out:
# (Index(['RA (deg)', 'Dec (deg)', 'MatchID', 'MatchRa', 'MatchDEC', 'dstArcSec',
#         'version', 'HIP', 'TYC', 'UCAC', 'TWOMASS', 'SDSS', 'ALLWISE', 'GAIA',
#         'APASS', 'KIC', 'objType', 'typeSrc', 'POSflag', 'pmRA', 'e_pmRA',
#         'pmDEC', 'e_pmDEC', 'PMflag', 'plx', 'e_plx', 'PARflag', 'gallong',
#         'gallat', 'eclong', 'eclat', 'Bmag', 'e_Bmag', 'Vmag', 'e_Vmag', 'umag',
#         'e_umag', 'gmag', 'e_gmag', 'rmag', 'e_rmag', 'imag', 'e_imag', 'zmag',
#         'e_zmag', 'Jmag', 'e_Jmag', 'Hmag', 'e_Hmag', 'Kmag', 'e_Kmag',
#         'TWOMflag', 'prox', 'w1mag', 'e_w1mag', 'w2mag', 'e_w2mag', 'w3mag',
#         'e_w3mag', 'w4mag', 'e_w4mag', 'GAIAmag', 'e_GAIAmag', 'Tmag', 'e_Tmag',
#         'TESSflag', 'SPFlag', 'Teff', 'e_Teff', 'logg', 'e_logg', 'MH', 'e_MH',
#         'rad', 'e_rad', 'mass', 'e_mass', 'rho', 'e_rho', 'lumclass', 'lum',
#         'e_lum', 'd', 'e_d', 'ebv', 'e_ebv', 'numcont', 'contratio',
# ...

# %%
plt.plot(sample['bestdist'],sample['adoptedJ'],'o')
plt.plot(tess["d"], tess["Jmag"],"o")
plt.xlabel('Distance (pc)')
plt.ylabel('J (mag)')
plt.xlim(0,30)
# Out:
# (0, 30)

# %%
kepler
# Out:
#     angDist        RA      DEC      KIC        RA_       Dec_  umag    gmag  \
# 0  0.532548  280.8422  40.6725  5421954  280.84213  40.672638   NaN  18.864
# 1  0.260515  281.3287  38.8902  3719645  281.32861  38.890182   NaN  20.348
#
#      rmag    imag  zmag    Jmag    Hmag    Kmag  kepmag  pmRA  pmDec  sg  v  \
# 0  17.283  16.614   NaN  11.313  10.688  10.308  17.286  -122    590   0  0
# 1  18.803  18.150   NaN  12.214  11.461  11.047  18.807   164    324   0  0
#
#       cq  aq  fc
# 0  PHOTO   0   1
# 1  PHOTO   0   1

# %%
kepler.columns[0:22],kepler.columns[22:],
# Out:
# (Index(['angDist', 'RA', 'DEC', 'KIC', 'RA_', 'Dec_', 'umag', 'gmag', 'rmag',
#         'imag', 'zmag', 'Jmag', 'Hmag', 'Kmag', 'kepmag', 'pmRA', 'pmDec', 'sg',
#         'v', 'cq', 'aq', 'fc'],
#        dtype='object'), Index([], dtype='object'))

# %%
plt.plot(sample['bestdist'],sample['adoptedJ'],'o')
plt.plot(kepler[""],kepler["Jmag"],'o')
plt.xlabel('Distance (pc)')
plt.ylabel('J (mag)')
plt.xlim(0,30)
# Out:
# (0, 30)
