# %%
from lightkurve import search_targetpixelfile

# %%
pixelfile = search_targetpixelfile("TIC8195886", sector=1).download(quality_bitmask='hardest');

# %%
pixelfile.plot(frame=1);

# %%
lc = pixelfile.to_lightcurve(aperture_mask='all');

# %%
lc.time, lc.flux
# Out:
# (array([1325.30123463, 1325.30262352, 1325.3040124 , ..., 1353.17842423,
#         1353.17981306, 1353.1812019 ]),
#  array([35415.07 , 35477.043, 35492.37 , ..., 35146.598, 35238.676,
#         35130.977], dtype=float32))

# %%
lc.plot();

# %%
pixelfile.show_properties()
# Out:
#    Attribute                                                                           Description
# --------------- ----------------------------------------------------------------------------------------------------------------------------------------------------------
#          camera                                                                                                                                                          1
#             ccd                                                                                                                                                          1
#          column                                                                                                                                                        106
#             row                                                                                                                                                       1741
#          sector                                                                                                                                                          1
#        targetid                                                                                                                                                    8195886
#         mission                                                                                                                                                       TESS
#            path /Users/student/.lightkurve-cache/mastDownload/TESS/tess2018206045859-s0001-0000000008195886-0120-s/tess2018206045859-s0001-0000000008195886-0120-s_tp.fits
# quality_bitmask                                                                                                                                                    hardest
#             hdu                                                                                                               PRIMARY, PIXELS, APERTURE, TARGET COSMIC RAY
# background_mask                                                                                                                                             array (11, 11)
#       cadenceno                                                                                                                                             array (18097,)
#            flux                                                                                                                                      array (18097, 11, 11)
#        flux_bkg                                                                                                                                      array (18097, 11, 11)
#    flux_bkg_err                                                                                                                                      array (18097, 11, 11)
#        flux_err                                                                                                                                      array (18097, 11, 11)
#   nan_time_mask                                                                                                                                             array (18097,)
#   pipeline_mask                                                                                                                                             array (11, 11)
#       pos_corr1                                                                                                                                             array (18097,)
#       pos_corr2                                                                                                                                             array (18097,)
#         quality                                                                                                                                             array (18097,)
#    quality_mask                                                                                                                                             array (20076,)
#            time                                                                                                                                             array (18097,)
#    astropy_time                                                                                                                           <class 'astropy.time.core.Time'>
#             dec                                                                                                                                            <class 'float'>
#          header                                                                                                                    <class 'astropy.io.fits.header.Header'>
#              ra                                                                                                                                            <class 'float'>
#           shape                                                                                                                                            <class 'tuple'>
#             wcs                                                                                                                                        astropy.wcs.wcs.WCS

# %%
pixelfile.sector
# Out:
# 1

# %%
pixelfile.flux
# Out:
# array([[[-2.4498690e+01, -2.3669207e+01, -1.8209314e+01, ...,
#           4.1097517e+00,  1.0405703e+01,  6.4275155e+00],
#         [-2.8251715e+01, -2.0023344e+01, -1.0839422e+01, ...,
#           2.4788227e+01,  4.1339481e+01,  1.3305880e+01],
#         [-2.2938040e+01, -1.2422761e+01, -1.3007475e-01, ...,
#           1.7581301e+01,  2.7435160e+01,  4.2327061e+00],
#         ...,
#         [ 6.4440094e+02,  9.9935675e+02,  8.2459985e+02, ...,
#           1.5238239e+00,  1.1598868e+01, -5.2694714e-01],
#         [ 1.0304847e+02,  6.1534656e+02,  6.3976904e+02, ...,
#           1.8032703e+00, -1.5051218e+01, -1.7348616e+01],
#         [ 3.4240807e+01,  1.3019168e+02,  1.4595901e+02, ...,
#          -1.3718699e+01, -1.9616020e+01, -2.1794144e+01]],
#
#        [[-2.4820541e+01, -2.5117981e+01, -1.9361389e+01, ...,
#           3.5329182e+00,  9.6211033e+00,  5.6670117e+00],
#         [-2.4585085e+01, -2.2469055e+01, -1.0995864e+01, ...,
#           2.3051006e+01,  3.9358089e+01,  1.7143173e+01],
#         [-2.6208363e+01, -1.4986186e+01, -4.5731158e+00, ...,
#           2.1607689e+01,  2.6661339e+01,  2.3862073e+00],
#         ...,
#         [ 6.7383643e+02,  1.0166376e+03,  8.2991193e+02, ...,
#           3.1461465e+00,  8.6047239e+00, -1.9010293e-01],
#         [ 9.7239517e+01,  6.1730536e+02,  6.6927185e+02, ...,
#           1.3655846e-01, -1.2670898e+01, -1.5000993e+01],
#         [ 3.3920166e+01,  1.3270888e+02,  1.5492978e+02, ...,
#          -1.3251832e+01, -2.1385321e+01, -2.1566126e+01]],
#
#        [[-2.5362234e+01, -2.3430462e+01, -1.9444887e+01, ...,
#           3.2520332e+00,  8.1417093e+00,  4.0887389e+00],
#         [-2.3133167e+01, -2.1760471e+01, -1.3164307e+01, ...,
#           2.7352566e+01,  3.8991024e+01,  1.4315045e+01],
#         [-2.2807707e+01, -1.5266978e+01, -1.4685326e+00, ...,
#           1.8974638e+01,  2.7496811e+01,  3.0024261e+00],
#         ...,
#         [ 6.8189423e+02,  1.0193171e+03,  8.4350256e+02, ...,
#           3.9663193e+00,  1.0466368e+01, -6.6725606e-01],
#         [ 1.0317884e+02,  6.1216077e+02,  6.7166144e+02, ...,
#           2.0458798e+00, -1.4099573e+01, -1.5419700e+01],
#         [ 3.5576714e+01,  1.3392258e+02,  1.5330792e+02, ...,
#          -1.1390774e+01, -2.1752869e+01, -2.1935347e+01]],
#
#        ...,
#
#        [[-2.7730204e+01, -2.3810575e+01, -2.4468891e+01, ...,
#          -3.0067520e+00,  4.0798407e+00,  2.9320507e+00],
#         [-2.7113625e+01, -2.3568920e+01, -1.4195955e+01, ...,
#           2.3647383e+01,  3.4933010e+01,  1.2538285e+01],
#         [-2.5168678e+01, -1.4791388e+01, -1.0759655e+00, ...,
#           2.3895716e+01,  3.0227549e+01,  5.2326651e+00],
#         ...,
#         [ 1.0613096e+03,  1.1158972e+03,  7.2901160e+02, ...,
#           7.2165542e+00,  1.6467264e+01,  3.7608755e+00],
#         [ 1.5354294e+02,  7.4565192e+02,  6.7717975e+02, ...,
#          -1.0613335e+00, -7.5520835e+00, -1.3133944e+01],
#         [ 4.5562290e+01,  2.1438812e+02,  1.8826318e+02, ...,
#          -1.2689969e+01, -1.6132105e+01, -2.0083527e+01]],
#
#        [[-2.4855673e+01, -2.4582783e+01, -1.7819389e+01, ...,
#           8.0714369e-01,  2.9875989e+00,  3.7090058e+00],
#         [-2.4231758e+01, -2.2803329e+01, -1.6872747e+01, ...,
#           2.9288818e+01,  3.5541325e+01,  1.1721175e+01],
#         [-2.3867355e+01, -1.8702610e+01, -6.9417114e+00, ...,
#           2.2913584e+01,  3.2523026e+01,  4.4153900e+00],
#         ...,
#         [ 1.1137982e+03,  1.1351704e+03,  7.3361371e+02, ...,
#           6.2331076e+00,  1.7006409e+01,  6.1788130e+00],
#         [ 1.5523611e+02,  7.4487964e+02,  6.9569897e+02, ...,
#          -4.5901725e-01, -5.4220591e+00, -1.0796153e+01],
#         [ 4.7032787e+01,  2.2181190e+02,  1.9723830e+02, ...,
#          -1.2082783e+01, -1.5630137e+01, -1.9358501e+01]],
#
#        [[-2.9422953e+01, -2.8298405e+01, -1.9310106e+01, ...,
#           3.6071160e+00,  2.3906875e+00,  6.4326124e+00],
#         [-3.1908707e+01, -2.1922041e+01, -1.5177368e+01, ...,
#           2.3978226e+01,  3.8335297e+01,  9.5589275e+00],
#         [-2.5333925e+01, -1.7760696e+01, -3.6501079e+00, ...,
#           2.2565540e+01,  3.3611629e+01,  3.8922346e+00],
#         ...,
#         [ 1.0613204e+03,  1.1095909e+03,  7.3496967e+02, ...,
#           5.8863783e+00,  1.6398893e+01,  7.7592742e-01],
#         [ 1.5222978e+02,  7.4267664e+02,  6.7740448e+02, ...,
#           7.2087246e-01, -9.2436609e+00, -1.2954414e+01],
#         [ 4.9125244e+01,  2.1141003e+02,  1.8964470e+02, ...,
#          -1.0895412e+01, -1.7826067e+01, -1.9988316e+01]]], dtype=float32)
